# %%
import numpy as np
import pandas as pd

# %%
us=pd.read_csv("C:\\Users\\Dell\\python\\class\\us_births.csv")
us.head()
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
usyear=np.array(us["year"])
usmonth=np.array(us["month"])
usday=np.array(us["day"])
usgender=np.array(us["gender"])
usbirth=np.array(us["births"])

# %%
mostgender=usgender[usbirth.argmax()]
mostgender
# Out:
# 'M'

# %%
male=[]
female=[]
for x,y in zip(usgender,usbirth):
    if x =="M":
        male.append(y)
    else:
        female.append(y)
male
# Out:
# [4440,
#  4548,
#  4994,
#  4520,
#  4198,
#  4850,
#  5092,
#  4934,
#  4842,
#  5190,
#  4598,
#  4324,
#  5076,
#  5296,
#  5096,
#  4872,
#  5030,
#  4642,
#  4452,
#  4924,
#  5432,
#  5088,
#  4660,
#  5046,
#  4674,
#  4338,
#  5046,
#  5172,
#  4880,
#  5006,
#  4912,
#  38,
#  4736,
#  4480,
#  5110,
#  5200,
#  5002,
#  4968,
#  5162,
#  4636,
#  4442,
#  4996,
#  5060,
#  5228,
#  4756,
#  5262,
#  4712,
#  4416,
#  5054,
#  5214,
#  5028,
#  5062,
#  4976,
#  4668,
#  4406,
#  5168,
#  5370,
#  5210,
#  5030,
#  4964,
#  16,
#  28,
#  20,
#  48,
#  4784,
#  4376,
#  5194,
#  5270,
#  5088,
#  5064,
#  5290,
#  4872,
#  4248,
#  5076,
#  5092,
#  4976,
#  4930,
#  5098,
#  4538,
#  4226,
#  5340,
#  5226,
#  5096,
#  5074,
#  5070,
#  4516,
#  4362,
#  5072,
#  5296,
#  4996,
#  5070,
#  5358,
#  4616,
#  4200,
#  5002,
#  50,
#  4970,
#  5212,
#  4848,
#  4854,
#  4364,
#  4112,
#  4956,
#  5246,
#  5104,
#  4978,
#  5072,
#  4622,
#  4248,
#  4840,
#  5364,
#  5036,
# ...

# %%
sum_of_malebirth=np.sum(male)
sum_of_malebirth
# Out:
# 77738555

# %%
arrmale=np.array(male)
arrmale.max()
# Out:
# 199622

# %%
sum_of_femalebirth=np.sum(female)
sum_of_femalebirth
# Out:
# 74035823

# %%
arrfemale=np.array(female)
arrfemale.max()
# Out:
# 191495

# %%
arr=np.array(us)

# %%
newarr=arr[:,[3,4]]
newarr
# Out:
# array([['F', 4046],
#        ['M', 4440],
#        ['F', 4454],
#        ...,
#        ['M', 165468],
#        ['F', 173215],
#        ['M', 181235]], dtype=object)
